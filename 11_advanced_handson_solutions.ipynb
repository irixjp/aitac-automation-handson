# %% [markdown]
# # 応用演習 解答例

# %% [markdown]
# ## Playbookの再利用

# %%
ansible-playbook -i inventories/ec2.py solutions/01_site.yml
# Out:
# PLAY [all] *********************************************************************
#
# TASK [ec2] *********************************************************************
# changed: [13.112.122.31]
#
# TASK [ec2_instance_facts] ******************************************************
# ok: [13.112.122.31]
#
# TASK [debug] *******************************************************************
# ok: [13.112.122.31] => {
#     "result": {
#         "changed": false,
#         "failed": false,
#         "instances": [
#             {
#                 "ami_launch_index": 0,
#                 "architecture": "x86_64",
#                 "block_device_mappings": [
#                     {
#                         "device_name": "/dev/sda1",
#                         "ebs": {
#                             "attach_time": "2017-12-31T11:48:16+00:00",
#                             "delete_on_termination": true,
#                             "status": "attached",
# ...

# %%
ansible-playbook -i inventories/ec2.py solutions/01_site.yml
# Out:
# PLAY [tag_automation_group_target] *********************************************
#
# TASK [TEST SSH port is up?] ****************************************************
# ok: [52.199.249.109]
# ok: [13.114.212.223]
#
# TASK [ping] ********************************************************************
# fatal: [13.114.212.223]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: Warning: Permanently added '13.114.212.223' (ECDSA) to the list of known hosts.\r\nPermission denied (publickey,gssapi-keyex,gssapi-with-mic).\r\n", "unreachable": true}
# fatal: [52.199.249.109]: UNREACHABLE! => {"changed": false, "msg": "Failed to connect to the host via ssh: Warning: Permanently added '52.199.249.109' (ECDSA) to the list of known hosts.\r\nPermission denied (publickey,gssapi-keyex,gssapi-with-mic).\r\n", "unreachable": true}
# 	to retry, use: --limit @/notebooks/aitac-automation-handson/solutions/01_site.retry
#
# ...
